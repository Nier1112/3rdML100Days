# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %% [markdown]
# # [作業目標]
# - 仿造範例的MAE函數, 自己寫一個MSE函數(參考上面公式)

# %% [markdown]
# # [作業重點]
# - 注意程式的縮排
# - 是否能將數學公式, 轉換為 Python 的函式組合? (In[2], Out[2])

# %%
# 載入基礎套件與代稱
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# 定義 mean_squared_error 這個函數, 計算並傳回 MSE
def mean_squared_error(X1,X2):
    """
    請完成這個 Function 後往下執行
    計算 MSE 
    """
    mse = MSE = sum((X1-X2)**2) / len(X1)
    return mse

# %%
# 與範例相同, 不另外解說
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
# 與範例相同, 不另外解說
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 197.106
# The Mean absolute error is 10.911

# %% [markdown]
# # [作業2]
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# 1. 你選的這組資料為何重要
#
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#
# 3. 蒐集而來的資料型態為何
#
# 4. 這組資料想解決的問題如何評估
#
# # [作業3]
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#
# 3. 蒐集而來的資料型態為何
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)

# %%
作業2：
Kaggle：https://www.kaggle.com/ceshine/impact-of-chinese-tourism-ban-to-taiwan
    標題：中國旅遊禁令對台灣旅遊產業影響的分析
1. 選這組資料為何重要?
A：這組資料可以明確的找出中國旅遊禁令對台灣整體觀光產業是沒有影響的。
2.資料從何而來?
A：這組資料由台灣觀光局(Taiwan Tourism Bureau)所統計的官方資料，
3. 蒐集而來的資料型態為何?
A：資料收集的型態為已經整理過的統計圖表
4. 這組資料想解決的問題如何評估?
A：除了觀光局的來台觀光人數整理資料，仍需要評估這些來台灣的人所花費的食衣住行等各項費用的統計，就可以知道中國旅遊禁令減少了來自中國的觀光收入
但仍有來自日本、新加坡、香港、澳門、韓國、馬來西亞...etc來自14個不同國家的消費。而中國觀光客的平均每日每人消費只佔全額8%，
因此可以說明中國旅遊禁令對於台灣觀光產業影響不大。反之仍須思考，如何改進才能夠提高來台旅遊人員消費的能力。
例如新加坡觀光客來台消費為第二名，在眾多項目之中娛樂費用最低，因此仍可針對來自新加坡的人喜好而在觀光地點找出其娛樂喜好而增設相關設施
以增進新加坡人來台觀光對娛樂的消費和回鍋率。其他依此類推。
觀光局的這組資料搭配以下資訊：http://admin.taiwan.net.tw/upload/contentFile/auser/b/annual_statistical_2016_htm/pic/p_23.jpg
    可以了解針對來台觀光的人員根據不同的國情習性和消費喜好而能夠推出適合的旅遊套餐方案。

# %%
作業3：
1. 定義提升業績：每一天的接客數量總額增加為y，而我假設自由載客車隊的地點選擇會影響載客數量總額
2. 因此假設接客地點、開車路線選擇和開車速度會影響到接客戶量總額，因此我們假設
車隊中每一台車的接客地點為X1，所選擇到達目標地點的路線為X2，而開車速度為X3，我們可以由車內安裝GPS了解X1、X2和X3的資訊
並由車隊美日繳回當天載客營業總額來做相關係數比對了解X1、X2、X3影響y的程度
3. 資料收集來的型態為結構化的數值表格
4. 透過(y, X1)和(y, X2)和(y, X3)的回歸關係可以理解這三點因素對於接客數量的總額增加相關程度多寡。並於了解後擬定方案改善實施，再次統計
資料以驗證，
假設接客數量增加與開車選擇路線有高度正向關係，則我們可以觀察A路線的開車速度以及B路線的開車速度是否影響接客數量。若每次都開A路線的接客數量較多
則可以兩組人馬進行驗證。一組人走A路線另外一組人走B路線。便可以理解此假設是否成立。
